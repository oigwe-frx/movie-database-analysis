# %% [markdown]
# <a href="https://colab.research.google.com/github/oigwe-frx/movie-database-analysis/blob/excellentwork_multivariate_analysis/Copy_of_Movie_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -------------------------------------
# # **Project 1: Movie Data Analysis**
# -------------------------------------

# %% [markdown]
# --------------------
# ## **Context**
# --------------------
#
# In an era marked by the convergence of technology and entertainment, the film industry is a pillar of global cultural dissemination and economic vitality. Understanding the intricate factors influencing a movie's commercial success is paramount within this dynamic landscape. Leveraging data from the Internet Movie Database (IMDb), this project aims to delve into the multifaceted realm of box office hits, dissecting the variables that potentially shape their triumph or demise.
#
# The cinematic ecosystem is a tapestry woven with diverse elements, ranging from star power and production budget to genre and critical reception. Against this backdrop, the analysis endeavors to discern patterns and correlations within the data, unraveling the enigmatic interplay between various attributes and a movie's financial performance.
#
# As the digital era reshapes audience preferences and consumption patterns, traditional metrics of success undergo a metamorphosis. Thus, this investigation seeks to illuminate established paradigms and explore emerging trends and disruptions catalyzed by technological advancements and shifting audience dynamics.
#
# By scrutinizing the data with a meticulous eye and employing sophisticated analytical methodologies, this project endeavors to offer insights that transcend conventional wisdom, providing stakeholders within the film industry with actionable intelligence to navigate an ever-evolving landscape and maximize their chances of crafting cinematic endeavors that resonate with audiences and thrive at the box office.
#
# ------------------
# ## **Objective**
# ------------------
#
# This data analysis and visualization project aims to investigate and identify critical attributes influencing the commercial success of movies. Leveraging data sourced from IMDb, the project aims to uncover patterns and correlations between various factors and a movie's box office performance. Through meticulous analysis and visualization techniques, the project seeks to provide actionable insights to stakeholders in the film industry, enabling them to make informed decisions to enhance the financial viability of their cinematic endeavors.
#
# -----------------------------
# ## **General Key Questions**
# -----------------------------
#
# - What is the dataset source for the visualization project, and how reliable and comprehensive is it?
#
# - How can data be cleaned and prepared for visualization to ensure accuracy and consistency?
#
# - What visualization techniques are most suitable for representing different data types and revealing insights?
#
# - How should the visualizations be designed to cater to the target audience and convey information efficiently?
#
# - Can any specific trends or patterns in the data be uncovered through visualization?
#
# - What are the key metrics and performance indicators to track the effectiveness of the visualization?
#
# - Can the visualization techniques be applied to different datasets and domains beyond the current project?
#
# - How can user feedback and iterative design processes be integrated to improve the effectiveness of the visualizations continuously?
#
# -----------------------------
# ## **Data Specific Key Questions**
# -----------------------------
# *   What are the most popular movies?
#   *   Determine the top-rated or most popular titles based on IMDb ratings or user reviews.
#
# * What are the trends in movie genres over time?
#     * Analyze how the popularity of different genres has evolved over the years.
#
# * Which actors have appeared in the most movies?
#     * Identify prolific actors and actresses in the IMDb database.
#
# * What are the highest-grossing movies of all time?
#     * Investigate box office revenue data to find the most financially successful films.
#
# * Are there any correlations between movie budgets and box office performance?
#     * Explore whether higher budgets lead to higher box office earnings.
#
# * What is the distribution of movie ratings on IMDb?
#     * Analyze the distribution of IMDb ratings to understand audience preferences.
#
# * What is the average movie runtime?
#     * Calculate the average duration of movies and see if there are any trends over time.
#
# * Who are the top-rated directors?
#     * Identify directors with the highest-rated movies in the database.
#
# * Are there any geographical trends in movie preferences?
#     * Explore whether movie preferences vary by region or country.
#
# * How has the film industry evolved over the years?
#     * Look at historical data to understand film production, technology, and distribution changes.
#
# * What are the most influential factors for IMDb ratings?
#     * Analyze which factors, genre, director, or cast impact ratings are most important.
#
# * Are there any outliers or anomalies in the data?
#     * Look for unusual or unexpected patterns in the data that may require further investigation.
#
# ------------------------------------
# ## **Dataset Description**
# ------------------------------------
#
# ### Data Description
#
# The data contains data related to a films, as compiled by the Internet Movie Database (IMDb). The detailed data dictionary is given below.
#
# ### Data Dictionary
#
# * names: movie name
# * date_x: release date
# * score: user rating
# * genre: genre of the movie
# * overview: a summary of the movie's plot
# * crew: crew members
# * orig_title: the original title of the movie
# * status: release status
# * orig_lang: originally released in this language
# * budget_x: movie budget
# * revenue: revenue generated worldwide
# * country: release country

# %% [markdown]
# ##  **Importing the necessary libraries and overview of the dataset**

# %%
# Library to suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Libraries to help with data visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Library to extract datetime features
import datetime as dt

from collections import Counter

# %% [markdown]
# ### **Loading the dataset**

# %%
data = pd.read_csv('/content/imdb_movies.csv')

# %%
# Copying data to another variable to avoid any changes to the original data
df = data.copy()

# %% [markdown]
# ## **Initial Data Exploration**

# %% [markdown]
# ### **View the first 5 rows of the dataset**

# %%
# Looking at head (the first 5 observations)
df.head()
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
#
#                     orig_title     status            orig_lang     budget_x  \
# 0                    Creed III   Released              English   75000000.0
# 1     Avatar: The Way of Water   Released              English  460000000.0
# 2  The Super Mario Bros. Movie   Released              English  100000000.0
# 3                       Momias   Released   Spanish, Castilian   12300000.0
# 4                    Supercell   Released              English   77000000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US

# %% [markdown]
# **Observations:**
#
# * ...

# %% [markdown]
# ### **View the last 5 rows of the dataset**

# %%
# Looking at tail (the last 5 observations)
df.tail()
# Out:
#                                          names       date_x  score  \
# 10173                       20th Century Women  12/28/2016    73.0
# 10174  Delta Force 2: The Colombian Connection  08/24/1990    54.0
# 10175                         The Russia House  12/21/1990    61.0
# 10176         Darkman II: The Return of Durant  07/11/1995    55.0
# 10177       The Swan Princess: A Royal Wedding  07/20/2020    70.0
#
#                                                    genre  \
# 10173                                              Drama
# 10174                                             Action
# 10175                           Drama, Thriller, Romance
# 10176  Action, Adventure, Science Fiction, Thriller, ...
# 10177                         Animation, Family, Fantasy
#
#                                                 overview  \
# 10173  In 1979 Santa Barbara, California, Dorothea Fi...
# 10174  When DEA agents are taken captive by a ruthles...
# 10175  Barley Scott Blair, a Lisbon-based editor of R...
# 10176  Darkman and Durant return and they hate each o...
# 10177  Princess Odette and Prince Derek are going to ...
#
#                                                     crew  \
# 10173  Annette Bening, Dorothea Fields, Lucas Jade Zu...
# 10174  Chuck Norris, Col. Scott McCoy, Billy Drago, R...
# 10175  Sean Connery, Bartholomew 'Barley' Scott Blair...
# 10176  Larry Drake, Robert G. Durant, Arnold Vosloo, ...
# 10177  Nina Herzog, Princess Odette (voice), Yuri Low...
#
#                                     orig_title     status orig_lang  \
# 10173                       20th Century Women   Released   English
# 10174  Delta Force 2: The Colombian Connection   Released   English
# 10175                         The Russia House   Released   English
# 10176         Darkman II: The Return of Durant   Released   English
# 10177       The Swan Princess: A Royal Wedding   Released   English
#
#           budget_x      revenue country
# 10173    7000000.0    9353729.0      US
# 10174    9145817.8    6698361.0      US
# 10175   21800000.0   22997992.0      US
# 10176  116000000.0  475661306.0      US
# 10177   92400000.0  539401838.6      GB

# %% [markdown]
# **Observations:**
#
# * ...

# %% [markdown]
# ### **Checking the shape of the dataset**

# %%
df.shape
# Out:
# (10178, 12)

# %% [markdown]
# ### **Checking the info()**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       10178 non-null  object
#  1   date_x      10178 non-null  object
#  2   score       10178 non-null  float64
#  3   genre       10093 non-null  object
#  4   overview    10178 non-null  object
#  5   crew        10122 non-null  object
#  6   orig_title  10178 non-null  object
#  7   status      10178 non-null  object
#  8   orig_lang   10178 non-null  object
#  9   budget_x    10178 non-null  float64
#  10  revenue     10178 non-null  float64
#  11  country     10178 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 954.3+ KB

# %% [markdown]
# **Observations:**
#
# * ...

# %% [markdown]
# ### **Summary of the data**

# %%
df.describe().T
# Out:
#             count          mean           std  min         25%          50%  \
# score     10178.0  6.349705e+01  1.353701e+01  0.0        59.0         65.0
# budget_x  10178.0  6.488238e+07  5.707565e+07  1.0  15000000.0   50000000.0
# revenue   10178.0  2.531401e+08  2.777880e+08  0.0  28588985.0  152934876.5
#
#                   75%           max
# score            71.0  1.000000e+02
# budget_x  105000000.0  4.600000e+08
# revenue   417802077.1  2.923706e+09

# %% [markdown]
# **By default, the describe() function shows the summary of numeric variables only. Let's check the summary of non-numeric variables.**

# %%
df.describe(exclude = 'number').T
# Out:
#             count unique                                                top  \
# names       10178   9660                                          Pinocchio
# date_x      10178   5688                                        04/07/2023
# genre       10093   2303                                              Drama
# overview    10178   9905  We don't have an overview translated in Englis...
# crew        10122   9927  Scout Taylor-Compton, Laurie Strode, Tyler Man...
# orig_title  10178   9736                                          Pinocchio
# status      10178      3                                           Released
# orig_lang   10178     54                                            English
# country     10178     60                                                 AU
#
#              freq
# names          12
# date_x         41
# genre         556
# overview       89
# crew            3
# orig_title     12
# status      10131
# orig_lang    7417
# country      4885

# %% [markdown]
# **Observations:**
#
# * ...

# %% [markdown]
# :**Let's check the count of each unique category in each of the categorical variables.**

# %%
# Making a list of all categorical variables


# Printing number of count of each unique value in each column

# %% [markdown]
# ## **Data Cleaning**

# %%
# Convert date_x to datetime, and  budget_x and revenue into integers:
df['date_x'] = pd.to_datetime(df['date_x'])
df['budget_x'] = df['budget_x'].astype(int)
df['revenue'] = df['revenue'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       10178 non-null  object
#  1   date_x      10178 non-null  datetime64[ns]
#  2   score       10178 non-null  float64
#  3   genre       10093 non-null  object
#  4   overview    10178 non-null  object
#  5   crew        10122 non-null  object
#  6   orig_title  10178 non-null  object
#  7   status      10178 non-null  object
#  8   orig_lang   10178 non-null  object
#  9   budget_x    10178 non-null  int64
#  10  revenue     10178 non-null  int64
#  11  country     10178 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 954.3+ KB

# %%
df
# Out:
#                                          names     date_x  score  \
# 0                                    Creed III 2023-03-02   73.0
# 1                     Avatar: The Way of Water 2022-12-15   78.0
# 2                  The Super Mario Bros. Movie 2023-04-05   76.0
# 3                                      Mummies 2023-01-05   70.0
# 4                                    Supercell 2023-03-17   61.0
# ...                                        ...        ...    ...
# 10173                       20th Century Women 2016-12-28   73.0
# 10174  Delta Force 2: The Colombian Connection 1990-08-24   54.0
# 10175                         The Russia House 1990-12-21   61.0
# 10176         Darkman II: The Return of Durant 1995-07-11   55.0
# 10177       The Swan Princess: A Royal Wedding 2020-07-20   70.0
#
#                                                    genre  \
# 0                                          Drama, Action
# 1                     Science Fiction, Adventure, Action
# 2          Animation, Adventure, Family, Fantasy, Comedy
# 3          Animation, Comedy, Family, Adventure, Fantasy
# 4                                                 Action
# ...                                                  ...
# 10173                                              Drama
# 10174                                             Action
# 10175                           Drama, Thriller, Romance
# 10176  Action, Adventure, Science Fiction, Thriller, ...
# 10177                         Animation, Family, Fantasy
#
#                                                 overview  \
# 0      After dominating the boxing world, Adonis Cree...
# 1      Set more than a decade after the events of the...
# 2      While working underground to fix a water main,...
# 3      Through a series of unfortunate events, three ...
# 4      Good-hearted teenager William always lived in ...
# ...                                                  ...
# 10173  In 1979 Santa Barbara, California, Dorothea Fi...
# 10174  When DEA agents are taken captive by a ruthles...
# 10175  Barley Scott Blair, a Lisbon-based editor of R...
# 10176  Darkman and Durant return and they hate each o...
# 10177  Princess Odette and Prince Derek are going to ...
#
#                                                     crew  \
# 0      Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1      Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2      Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3      Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4      Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# ...                                                  ...
# 10173  Annette Bening, Dorothea Fields, Lucas Jade Zu...
# 10174  Chuck Norris, Col. Scott McCoy, Billy Drago, R...
# 10175  Sean Connery, Bartholomew 'Barley' Scott Blair...
# 10176  Larry Drake, Robert G. Durant, Arnold Vosloo, ...
# 10177  Nina Herzog, Princess Odette (voice), Yuri Low...
#
#                                     orig_title     status  \
# 0                                    Creed III   Released
# 1                     Avatar: The Way of Water   Released
# 2                  The Super Mario Bros. Movie   Released
# 3                                       Momias   Released
# 4                                    Supercell   Released
# ...                                        ...        ...
# 10173                       20th Century Women   Released
# 10174  Delta Force 2: The Colombian Connection   Released
# 10175                         The Russia House   Released
# 10176         Darkman II: The Return of Durant   Released
# 10177       The Swan Princess: A Royal Wedding   Released
#
#                  orig_lang   budget_x     revenue country
# 0                  English   75000000   271616668      AU
# 1                  English  460000000  2316794914      AU
# 2                  English  100000000   724459031      AU
# 3       Spanish, Castilian   12300000    34200000      AU
# 4                  English   77000000   340941958      US
# ...                    ...        ...         ...     ...
# 10173              English    7000000     9353729      US
# 10174              English    9145817     6698361      US
# 10175              English   21800000    22997992      US
# 10176              English  116000000   475661306      US
# 10177              English   92400000   539401838      GB
#
# [10178 rows x 12 columns]

# %%
# Modified code from ChatGPT
# Identify duplicates (marking all duplicates as True, the first occurrence as False by default)
duplicates = df.duplicated(keep='first')

# Count duplicates
num_duplicates = duplicates.sum()

# Display the number of duplicates
print(f"Number of duplicate rows: {num_duplicates}")

# Review duplicate rows to understand what's being duplicated
print("Duplicate rows:")
df[duplicates]

#
# Out:
# Number of duplicate rows: 0
# Duplicate rows:
# Empty DataFrame
# Columns: [names, date_x, score, genre, overview, crew, orig_title, status, orig_lang, budget_x, revenue, country]
# Index: []

# %%
# Display column names
df.columns
# Out:
# Index(['names', 'date_x', 'score', 'genre', 'overview', 'crew', 'orig_title',
#        'status', 'orig_lang', 'budget_x', 'revenue', 'country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       10178 non-null  object
#  1   date_x      10178 non-null  datetime64[ns]
#  2   score       10178 non-null  float64
#  3   genre       10093 non-null  object
#  4   overview    10178 non-null  object
#  5   crew        10122 non-null  object
#  6   orig_title  10178 non-null  object
#  7   status      10178 non-null  object
#  8   orig_lang   10178 non-null  object
#  9   budget_x    10178 non-null  int64
#  10  revenue     10178 non-null  int64
#  11  country     10178 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 954.3+ KB

# %%
# Identify columns with null data and how many items.
df.isna().sum()
# Out:
# names          0
# date_x         0
# score          0
# genre         85
# overview       0
# crew          56
# orig_title     0
# status         0
# orig_lang      0
# budget_x       0
# revenue        0
# country        0
# dtype: int64

# %%
# Display sample rows with null values for genre
df[df['genre'].isnull()].head(10)
# Out:
#                                   names     date_x  score genre  \
# 305    Housewife Sex Slaves: Hatano Yui 2015-01-09    0.0   NaN
# 1174            Beauty Rope Cosmetology 1983-12-02   10.0   NaN
# 1561                            Reclaim 2022-07-29   20.0   NaN
# 1762         Ancient Chinese Whorehouse 1994-09-15   50.0   NaN
# 1776  Porno document: Toruko tokkyû bin 1982-02-26  100.0   NaN
# 2020             Moses, Prince of Egypt 2000-01-01   56.0   NaN
# 2144         My Beautiful Man ～eternal～ 2023-04-07    0.0   NaN
# 2267             Office Lady Rope Slave 1981-01-23   20.0   NaN
# 2317                 Dream to be a Wife 2015-09-09    0.0   NaN
# 2431                             Barbie 1977-01-01   20.0   NaN
#
#                                                overview  \
# 305   We don't have an overview translated in Englis...
# 1174  Miki is the daughter of an affluent family. Sh...
# 1561  She is a good woman living a fulfilling life. ...
# 1762  Madam Five and carpenter Kong work together ma...
# 1776                                   Pinku from 1982.
# 2020  At birth, Moses, a Hebrew baby is abandoned on...
# 2144  We don't have an overview translated in Englis...
# 2267  Two assistants to an S&M photographer decide t...
# 2317  We don't have an overview translated in Englis...
# 2431  Barbie comes home from shopping. She takes her...
#
#                                                    crew  \
# 305                                        Yui Hatano,
# 1174  Miki Takakura, Miki, Maya Ito, Rena, Ren Osugi...
# 1561                                                NaN
# 1762  Kent Cheng, Kong, Yvonne Yung Hung, Miss Ng, S...
# 1776  Jun Miho, , Rumi Kagawa, , Miyuki Oka, , Kayok...
# 2020                                                NaN
# 2144                      Riku Hagiwara, , Yusei Yagi,
# 2267  Junko Mabuki, Kimiyo Ezaki, Asami Ogawa, Kikuk...
# 2317                                        Ai Uehara,
# 2431                                                NaN
#
#                   orig_title     status     orig_lang   budget_x     revenue  \
# 305              人妻性奴隷 波多野結衣   Released      Japanese  167540000   175269998
# 1174               団鬼六　美女縄化粧   Released      Japanese  201940000    38157314
# 1561                 Reclaim   Released       Chinese   12001040    38139010
# 1762                   青樓十二房   Released     Cantonese  163600000   812667214
# 1776        ポルノドキュメント　トルコ特急便   Released      Japanese  201000000  1569323843
# 2020  Moses, Prince of Egypt   Released       English   80300000   321306715
# 2144           美しい彼～eternal～   Released      Japanese  167540000   175269998
# 2267               団鬼六　ＯＬ縄奴隷   Released      Japanese   12001040    38139010
# 2317               欲望人妻：滴垂之蜜   Released       Chinese  167540000   175269998
# 2431                  Barbie   Released   No Language   12001040    38139010
#
#      country
# 305       JP
# 1174      JP
# 1561      US
# 1762      HK
# 1776      JP
# 2020      AU
# 2144      JP
# 2267      JP
# 2317      CN
# 2431      US

# %%
# Display sample rows with null values for crew
df[df['crew'].isnull()].head(10)
# Out:
#                                                   names     date_x  score  \
# 148                   Orgasm Inc: The Story of OneTaste 2022-11-05   64.0
# 206   Legend of the Galactic Heroes: Die Neue These ... 2022-09-30   61.0
# 649                   Cuento de Primavera-A Spring Tale 2022-12-20   81.0
# 938              Cat Pack: A PAW Patrol Exclusive Event 2022-06-24   74.0
# 1561                                            Reclaim 2022-07-29   20.0
# 1752                       Avatar: Scene Deconstruction 2009-12-18   71.0
# 1828            Cyber Hell: Exposing an Internet Horror 2022-05-18   73.0
# 1881                     Guinea Pig: Devil's Experiment 1985-09-04   47.0
# 2020                             Moses, Prince of Egypt 2000-01-01   56.0
# 2431                                             Barbie 1977-01-01   20.0
#
#                         genre  \
# 148               Documentary
# 206                 Animation
# 649   Drama, Fantasy, Mystery
# 938         Animation, Family
# 1561                      NaN
# 1752              Documentary
# 1828              Documentary
# 1881                   Horror
# 2020                      NaN
# 2431                      NaN
#
#                                                overview crew  \
# 148   A sexual wellness company gains fame and follo...  NaN
# 206   The story focuses on the exploits of rivals Re...  NaN
# 649   We don't have an overview translated in Englis...  NaN
# 938   When Mayor Humdinger transforms his robot cat ...  NaN
# 1561  She is a good woman living a fulfilling life. ...  NaN
# 1752   The deconstruction of the Avatar scenes and sets  NaN
# 1828  Anonymous and exploitative, a network of onlin...  NaN
# 1881  A group of guys capture a young girl with the ...  NaN
# 2020  At birth, Moses, a Hebrew baby is abandoned on...  NaN
# 2431  Barbie comes home from shopping. She takes her...  NaN
#
#                                   orig_title     status            orig_lang  \
# 148        Orgasm Inc: The Story of OneTaste   Released              English
# 206               銀河英雄伝説 Die Neue These 策謀 1   Released             Japanese
# 649        Cuento de Primavera-A Spring Tale   Released   Spanish, Castilian
# 938   Cat Pack: A PAW Patrol Exclusive Event   Released              English
# 1561                                 Reclaim   Released              Chinese
# 1752            Avatar: Scene Deconstruction   Released              English
# 1828                      사이버 지옥: n번방을 무너뜨려라   Released               Korean
# 1881                            ギニーピッグ 悪魔の実験   Released             Japanese
# 2020                  Moses, Prince of Egypt   Released              English
# 2431                                  Barbie   Released          No Language
#
#        budget_x    revenue country
# 148    77400000  431611098      US
# 206   138000000  337725907      JP
# 649    77600000  827017257      US
# 938    92800000  609222681      US
# 1561   12001040   38139010      US
# 1752   90100000  414551647      US
# 1828   53600000  682429959      KR
# 1881   57800000  519287241      US
# 2020   80300000  321306715      AU
# 2431   12001040   38139010      US

# %%
# Remove all null values
df.dropna(inplace=True)
# reset index
df.reset_index()
df
# Out:
#                                          names     date_x  score  \
# 0                                    Creed III 2023-03-02   73.0
# 1                     Avatar: The Way of Water 2022-12-15   78.0
# 2                  The Super Mario Bros. Movie 2023-04-05   76.0
# 3                                      Mummies 2023-01-05   70.0
# 4                                    Supercell 2023-03-17   61.0
# ...                                        ...        ...    ...
# 10173                       20th Century Women 2016-12-28   73.0
# 10174  Delta Force 2: The Colombian Connection 1990-08-24   54.0
# 10175                         The Russia House 1990-12-21   61.0
# 10176         Darkman II: The Return of Durant 1995-07-11   55.0
# 10177       The Swan Princess: A Royal Wedding 2020-07-20   70.0
#
#                                                    genre  \
# 0                                          Drama, Action
# 1                     Science Fiction, Adventure, Action
# 2          Animation, Adventure, Family, Fantasy, Comedy
# 3          Animation, Comedy, Family, Adventure, Fantasy
# 4                                                 Action
# ...                                                  ...
# 10173                                              Drama
# 10174                                             Action
# 10175                           Drama, Thriller, Romance
# 10176  Action, Adventure, Science Fiction, Thriller, ...
# 10177                         Animation, Family, Fantasy
#
#                                                 overview  \
# 0      After dominating the boxing world, Adonis Cree...
# 1      Set more than a decade after the events of the...
# 2      While working underground to fix a water main,...
# 3      Through a series of unfortunate events, three ...
# 4      Good-hearted teenager William always lived in ...
# ...                                                  ...
# 10173  In 1979 Santa Barbara, California, Dorothea Fi...
# 10174  When DEA agents are taken captive by a ruthles...
# 10175  Barley Scott Blair, a Lisbon-based editor of R...
# 10176  Darkman and Durant return and they hate each o...
# 10177  Princess Odette and Prince Derek are going to ...
#
#                                                     crew  \
# 0      Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1      Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2      Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3      Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4      Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# ...                                                  ...
# 10173  Annette Bening, Dorothea Fields, Lucas Jade Zu...
# 10174  Chuck Norris, Col. Scott McCoy, Billy Drago, R...
# 10175  Sean Connery, Bartholomew 'Barley' Scott Blair...
# 10176  Larry Drake, Robert G. Durant, Arnold Vosloo, ...
# 10177  Nina Herzog, Princess Odette (voice), Yuri Low...
#
#                                     orig_title     status  \
# 0                                    Creed III   Released
# 1                     Avatar: The Way of Water   Released
# 2                  The Super Mario Bros. Movie   Released
# 3                                       Momias   Released
# 4                                    Supercell   Released
# ...                                        ...        ...
# 10173                       20th Century Women   Released
# 10174  Delta Force 2: The Colombian Connection   Released
# 10175                         The Russia House   Released
# 10176         Darkman II: The Return of Durant   Released
# 10177       The Swan Princess: A Royal Wedding   Released
#
#                  orig_lang   budget_x     revenue country
# 0                  English   75000000   271616668      AU
# 1                  English  460000000  2316794914      AU
# 2                  English  100000000   724459031      AU
# 3       Spanish, Castilian   12300000    34200000      AU
# 4                  English   77000000   340941958      US
# ...                    ...        ...         ...     ...
# 10173              English    7000000     9353729      US
# 10174              English    9145817     6698361      US
# 10175              English   21800000    22997992      US
# 10176              English  116000000   475661306      US
# 10177              English   92400000   539401838      GB
#
# [10052 rows x 12 columns]

# %%
# Rename Columns:
df= df.rename(columns={
    'names':'Title',
    'date_x':'Date',
    'score':'Rating',
    'genre':'Genre',
    'overview':'Overview',
    'crew':'Actor',
    'orig_title':'Orginal Title',
    'status':'Status',
    'orig_lang':'Orginal Language',
    'budget_x':'Budget',
    'revenue':'Revenue',
    'country':'Country'
}
)

# %%
df
# Out:
#                                          Title       Date  Rating  \
# 0                                    Creed III 2023-03-02    73.0
# 1                     Avatar: The Way of Water 2022-12-15    78.0
# 2                  The Super Mario Bros. Movie 2023-04-05    76.0
# 3                                      Mummies 2023-01-05    70.0
# 4                                    Supercell 2023-03-17    61.0
# ...                                        ...        ...     ...
# 10173                       20th Century Women 2016-12-28    73.0
# 10174  Delta Force 2: The Colombian Connection 1990-08-24    54.0
# 10175                         The Russia House 1990-12-21    61.0
# 10176         Darkman II: The Return of Durant 1995-07-11    55.0
# 10177       The Swan Princess: A Royal Wedding 2020-07-20    70.0
#
#                                                    Genre  \
# 0                                          Drama, Action
# 1                     Science Fiction, Adventure, Action
# 2          Animation, Adventure, Family, Fantasy, Comedy
# 3          Animation, Comedy, Family, Adventure, Fantasy
# 4                                                 Action
# ...                                                  ...
# 10173                                              Drama
# 10174                                             Action
# 10175                           Drama, Thriller, Romance
# 10176  Action, Adventure, Science Fiction, Thriller, ...
# 10177                         Animation, Family, Fantasy
#
#                                                 Overview  \
# 0      After dominating the boxing world, Adonis Cree...
# 1      Set more than a decade after the events of the...
# 2      While working underground to fix a water main,...
# 3      Through a series of unfortunate events, three ...
# 4      Good-hearted teenager William always lived in ...
# ...                                                  ...
# 10173  In 1979 Santa Barbara, California, Dorothea Fi...
# 10174  When DEA agents are taken captive by a ruthles...
# 10175  Barley Scott Blair, a Lisbon-based editor of R...
# 10176  Darkman and Durant return and they hate each o...
# 10177  Princess Odette and Prince Derek are going to ...
#
#                                                    Actor  \
# 0      Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1      Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2      Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3      Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4      Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# ...                                                  ...
# 10173  Annette Bening, Dorothea Fields, Lucas Jade Zu...
# 10174  Chuck Norris, Col. Scott McCoy, Billy Drago, R...
# 10175  Sean Connery, Bartholomew 'Barley' Scott Blair...
# 10176  Larry Drake, Robert G. Durant, Arnold Vosloo, ...
# 10177  Nina Herzog, Princess Odette (voice), Yuri Low...
#
#                                  Orginal Title     Status  \
# 0                                    Creed III   Released
# 1                     Avatar: The Way of Water   Released
# 2                  The Super Mario Bros. Movie   Released
# 3                                       Momias   Released
# 4                                    Supercell   Released
# ...                                        ...        ...
# 10173                       20th Century Women   Released
# 10174  Delta Force 2: The Colombian Connection   Released
# 10175                         The Russia House   Released
# 10176         Darkman II: The Return of Durant   Released
# 10177       The Swan Princess: A Royal Wedding   Released
#
#           Orginal Language     Budget     Revenue Country
# 0                  English   75000000   271616668      AU
# 1                  English  460000000  2316794914      AU
# 2                  English  100000000   724459031      AU
# 3       Spanish, Castilian   12300000    34200000      AU
# 4                  English   77000000   340941958      US
# ...                    ...        ...         ...     ...
# 10173              English    7000000     9353729      US
# 10174              English    9145817     6698361      US
# 10175              English   21800000    22997992      US
# 10176              English  116000000   475661306      US
# 10177              English   92400000   539401838      GB
#
# [10052 rows x 12 columns]

# %%
# Split the 'Names' column into separate columns
# expand=True will expand the split strings into separate columns
df_split = df['Actor'].str.split(',', expand=True)

# Rename columns for clarity (optional)
df_split.columns = [f'Actor_{i+1}' for i in range(df_split.shape[1])]

# Display the result
df_split
# Out:
#                  Actor_1                            Actor_2  \
# 0      Michael B. Jordan                       Adonis Creed
# 1        Sam Worthington                         Jake Sully
# 2            Chris Pratt                      Mario (voice)
# 3         Óscar Barberán                       Thut (voice)
# 4           Skeet Ulrich                        Roy Cameron
# ...                  ...                                ...
# 10173     Annette Bening                    Dorothea Fields
# 10174       Chuck Norris                   Col. Scott McCoy
# 10175       Sean Connery   Bartholomew 'Barley' Scott Blair
# 10176        Larry Drake                   Robert G. Durant
# 10177        Nina Herzog            Princess Odette (voice)
#
#                   Actor_3                     Actor_4            Actor_5  \
# 0          Tessa Thompson               Bianca Taylor    Jonathan Majors
# 1             Zoe Saldaña                     Neytiri   Sigourney Weaver
# 2         Anya Taylor-Joy      Princess Peach (voice)        Charlie Day
# 3       Ana Esther Alborg               Nefer (voice)   Luis Pérez Reina
# 4              Anne Heche              Dr Quinn Brody      Daniel Diemer
# ...                   ...                         ...                ...
# 10173   Lucas Jade Zumann                Jamie Fields       Greta Gerwig
# 10174         Billy Drago                 Ramon Cotta       John P. Ryan
# 10175   Michelle Pfeiffer                Katya Orlova       Roy Scheider
# 10176       Arnold Vosloo   Darkman / Peyton Westlake        Kim Delaney
# 10177      Yuri Lowenthal        Prince Derek (voice)          Vivian Lu
#
#                            Actor_6                  Actor_7  \
# 0                  Damien Anderson              Wood Harris
# 1       Kiri / Dr. Grace Augustine             Stephen Lang
# 2                    Luigi (voice)               Jack Black
# 3                  Carnaby (voice)         María Luisa Solá
# 4                    William Brody   Jordan Kristine Seamón
# ...                            ...                      ...
# 10173                 Abbie Porter             Elle Fanning
# 10174                  Gen. Taylor          Richard Jaeckel
# 10175                      Russell                James Fox
# 10176                 Jill Randall           Renee O'Connor
# 10177                         Fang           Joseph Medrano
#
#                          Actor_8              Actor_9              Actor_10  \
# 0       Tony 'Little Duke' Evers      Phylicia Rashād       Mary Anne Creed
# 1         Colonel Miles Quaritch         Kate Winslet                 Ronal
# 2                 Bowser (voice)   Keegan-Michael Key          Toad (voice)
# 3                  Madre (voice)           Jaume Solà        Sekhem (voice)
# 4                  Harper Hunter         Alec Baldwin           Zane Rogers
# ...                          ...                  ...                   ...
# 10173               Julie Miller         Billy Crudup               William
# 10174        DEA Agent John Page        Begonya Plaza    Quiquina Esquintla
# 10175                        Ned         John Mahoney                 Brady
# 10176            Laurie Brinkman        Lawrence Dane   Dr. Alfred Hathaway
# 10177                Lord Rogers      Christine Lakin          Queen Uberta
#
#        ...                   Actor_15         Actor_16               Actor_17  \
# 0      ...         José Benavidez Jr.     Felix Chavez          Selenis Leyva
# 1      ...                CCH Pounder            Mo'at             Edie Falco
# 2      ...   Kevin Michael Richardson    Kamek (voice)   Sebastian Maniscalco
# 3      ...            Aleix Estadella   Dennis (voice)         María Moscardó
# 4      ...              Johnny Wactor           Martin            Anjul Nigam
# ...    ...                        ...              ...                    ...
# 10173  ...       Vitaly Andrew LeBeau      Young Jamie            Olivia Hone
# 10174  ...              Mark Margolis      Gen. Olmedo            Mateo Gómez
# 10175  ...                Ken Russell           Walter        David Threlfall
# 10176  ...                David Ferry            Eddie         Jack Langedijk
# 10177  ...             Alexandre Chen             Chen               Hao Feng
#
#                        Actor_18 Actor_19 Actor_20 Actor_21 Actor_22 Actor_23  \
# 0                  Laura Chavez     None     None     None     None     None
# 1       General Frances Ardmore     None     None     None     None     None
# 2                 Spike (voice)     None     None     None     None     None
# 3                   Usi (voice)     None     None     None     None     None
# 4                        Ramesh     None     None     None     None     None
# ...                         ...      ...      ...      ...      ...      ...
# 10173            Julie's Sister     None     None     None     None     None
# 10174            Ernesto Flores     None     None     None     None     None
# 10175                   Wicklow     None     None     None     None     None
# 10176              Rollo Latham     None     None     None     None     None
# 10177      Chen (singing voice)     None     None     None     None     None
#
#       Actor_24
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 10173     None
# 10174     None
# 10175     None
# 10176     None
# 10177     None
#
# [10052 rows x 24 columns]

# %%
df
# Out:
#                                          Title       Date  Rating  \
# 0                                    Creed III 2023-03-02    73.0
# 1                     Avatar: The Way of Water 2022-12-15    78.0
# 2                  The Super Mario Bros. Movie 2023-04-05    76.0
# 3                                      Mummies 2023-01-05    70.0
# 4                                    Supercell 2023-03-17    61.0
# ...                                        ...        ...     ...
# 10173                       20th Century Women 2016-12-28    73.0
# 10174  Delta Force 2: The Colombian Connection 1990-08-24    54.0
# 10175                         The Russia House 1990-12-21    61.0
# 10176         Darkman II: The Return of Durant 1995-07-11    55.0
# 10177       The Swan Princess: A Royal Wedding 2020-07-20    70.0
#
#                                                    Genre  \
# 0                                          Drama, Action
# 1                     Science Fiction, Adventure, Action
# 2          Animation, Adventure, Family, Fantasy, Comedy
# 3          Animation, Comedy, Family, Adventure, Fantasy
# 4                                                 Action
# ...                                                  ...
# 10173                                              Drama
# 10174                                             Action
# 10175                           Drama, Thriller, Romance
# 10176  Action, Adventure, Science Fiction, Thriller, ...
# 10177                         Animation, Family, Fantasy
#
#                                                 Overview  \
# 0      After dominating the boxing world, Adonis Cree...
# 1      Set more than a decade after the events of the...
# 2      While working underground to fix a water main,...
# 3      Through a series of unfortunate events, three ...
# 4      Good-hearted teenager William always lived in ...
# ...                                                  ...
# 10173  In 1979 Santa Barbara, California, Dorothea Fi...
# 10174  When DEA agents are taken captive by a ruthles...
# 10175  Barley Scott Blair, a Lisbon-based editor of R...
# 10176  Darkman and Durant return and they hate each o...
# 10177  Princess Odette and Prince Derek are going to ...
#
#                                                    Actor  \
# 0      Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1      Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2      Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3      Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4      Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# ...                                                  ...
# 10173  Annette Bening, Dorothea Fields, Lucas Jade Zu...
# 10174  Chuck Norris, Col. Scott McCoy, Billy Drago, R...
# 10175  Sean Connery, Bartholomew 'Barley' Scott Blair...
# 10176  Larry Drake, Robert G. Durant, Arnold Vosloo, ...
# 10177  Nina Herzog, Princess Odette (voice), Yuri Low...
#
#                                  Orginal Title     Status  \
# 0                                    Creed III   Released
# 1                     Avatar: The Way of Water   Released
# 2                  The Super Mario Bros. Movie   Released
# 3                                       Momias   Released
# 4                                    Supercell   Released
# ...                                        ...        ...
# 10173                       20th Century Women   Released
# 10174  Delta Force 2: The Colombian Connection   Released
# 10175                         The Russia House   Released
# 10176         Darkman II: The Return of Durant   Released
# 10177       The Swan Princess: A Royal Wedding   Released
#
#           Orginal Language     Budget     Revenue Country
# 0                  English   75000000   271616668      AU
# 1                  English  460000000  2316794914      AU
# 2                  English  100000000   724459031      AU
# 3       Spanish, Castilian   12300000    34200000      AU
# 4                  English   77000000   340941958      US
# ...                    ...        ...         ...     ...
# 10173              English    7000000     9353729      US
# 10174              English    9145817     6698361      US
# 10175              English   21800000    22997992      US
# 10176              English  116000000   475661306      US
# 10177              English   92400000   539401838      GB
#
# [10052 rows x 12 columns]

# %%
top_10_revenues = df.sort_values("Revenue",ascending=False)[0:10]
top_10_revenues
# Out:
#                                        Title       Date  Rating  \
# 68                                    Avatar 2009-12-17    76.0
# 230                        Avengers: Endgame 2019-04-24    83.0
# 1                   Avatar: The Way of Water 2022-12-15    78.0
# 309                                  Titanic 1997-12-18    79.0
# 6670                                 Titanic 1953-04-11    66.0
# 4483    Louis Tomlinson: All of Those Voices 2023-03-22    91.0
# 943             Star Wars: The Force Awakens 2015-12-17    73.0
# 104                   Avengers: Infinity War 2018-04-25    83.0
# 76                   Spider-Man: No Way Home 2021-12-16    80.0
# 2156  BTS: Permission to Dance on Stage - LA 2022-09-08    92.0
#
#                                             Genre  \
# 68    Action, Adventure, Fantasy, Science Fiction
# 230            Adventure, Science Fiction, Action
# 1              Science Fiction, Adventure, Action
# 309                                Drama, Romance
# 6670                               Drama, Romance
# 4483                           Documentary, Music
# 943   Adventure, Action, Science Fiction, Fantasy
# 104            Adventure, Action, Science Fiction
# 76             Action, Adventure, Science Fiction
# 2156                           Music, Documentary
#
#                                                Overview  \
# 68    In the 22nd century, a paraplegic Marine is di...
# 230   After the devastating events of Avengers: Infi...
# 1     Set more than a decade after the events of the...
# 309   101-year-old Rose DeWitt Bukater tells the sto...
# 6670  Unhappily married, Julia Sturges decides to go...
# 4483  Ditching the typical glossy sheen of celebrity...
# 943   Thirty years after defeating the Galactic Empi...
# 104   As the Avengers and their allies have continue...
# 76    Peter Parker is unmasked and no longer able to...
# 2156  Purple colors the city of Los Angeles, as BTS ...
#
#                                                   Actor  \
# 68    Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 230   Robert Downey Jr., Tony Stark / Iron Man, Chri...
# 1     Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 309   Leonardo DiCaprio, Jack Dawson, Kate Winslet, ...
# 6670  Clifton Webb, Richard Ward Sturges, Barbara St...
# 4483  Louis Tomlinson, Self, Oliver Wright, Louis’ P...
# 943   Harrison Ford, Han Solo, Mark Hamill, Luke Sky...
# 104   Robert Downey Jr., Tony Stark / Iron Man, Chri...
# 76    Tom Holland, Peter Parker / Spider-Man, Zenday...
# 2156  Kim Nam-joon, Self, Kim Seok-jin, Self, Min Yo...
#
#                               Orginal Title     Status Orginal Language  \
# 68                                   Avatar   Released          English
# 230                       Avengers: Endgame   Released          English
# 1                  Avatar: The Way of Water   Released          English
# 309                                 Titanic   Released          English
# 6670                                Titanic   Released          English
# 4483   Louis Tomlinson: All of Those Voices   Released          English
# 943            Star Wars: The Force Awakens   Released          English
# 104                  Avengers: Infinity War   Released          English
# 76                  Spider-Man: No Way Home   Released          English
# 2156   BTS: PERMISSION TO DANCE 온 스테이지 – LA   Released           Korean
#
#          Budget     Revenue Country
# 68    237000000  2923706026      AU
# 230   400000000  2794731755      AU
# 1     460000000  2316794914      AU
# 309   200000000  2222985568      AU
# 6670  200000000  2222985568      US
# 4483  178800000  2081794005      GB
# 943   245000000  2068223624      AU
# 104   300000000  2048359754      AU
# 76    200000000  1910048245      AU
# 2156  215600000  1748017438      KR

# %%
df['Status'].value_counts()
# Out:
#  Released           10007
#  Post Production       30
#  In Production         15
# Name: Status, dtype: int64

# %%
df['Orginal Language'].value_counts()
# Out:
#  English                                7381
#  Japanese                                675
#  Spanish, Castilian                      388
#  Korean                                  384
#  French                                  282
#  Chinese                                 144
#  Italian                                 142
#  Cantonese                               141
#  German                                   89
#  Russian                                  65
#  Tagalog                                  42
#  Portuguese                               35
#  Thai                                     33
#  Norwegian                                29
#  Hindi                                    26
#  Polish                                   26
#  Danish                                   23
#  Swedish                                  22
#  Turkish                                  21
#  Dutch, Flemish                           21
#  Indonesian                               11
#  Telugu                                    6
#  Greek                                     6
#  Finnish                                   6
#  Tamil                                     5
#  Ukrainian                                 4
#  Persian                                   4
#  Arabic                                    4
#  Malayalam                                 3
#  Vietnamese                                3
#  Icelandic                                 3
#  Catalan, Valencian                        2
#  Hungarian                                 2
#  Romanian                                  2
#  Kannada                                   2
#  Czech                                     2
#  Malay                                     2
#  Irish                                     1
#  No Language                               1
#  Dzongkha                                  1
#  Latin                                     1
#  Serbo-Croatian                            1
#  Gujarati                                  1
#  Basque                                    1
#  Central Khmer                             1
#  Macedonian                                1
#  Latvian                                   1
#  Bokmål, Norwegian, Norwegian Bokmål       1
#  Bengali                                   1
#  Oriya                                     1
#  Galician                                  1
#  Serbian                                   1
#  Slovak                                    1
# Name: Orginal Language, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# AU    4880
# US    2716
# JP     502
# KR     358
# FR     219
# GB     172
# ES     151
# IT     123
# HK     120
# MX     102
# CN      86
# DE      85
# CA      67
# RU      52
# PH      42
# AR      40
# BR      38
# IN      35
# TH      29
# DK      24
# PL      22
# TR      19
# NO      16
# NL      15
# CO      14
# TW      12
# IE      11
# ID      11
# CL       9
# SE       9
# PE       7
# FI       6
# BE       6
# GR       6
# SU       5
# UA       4
# SG       4
# CH       4
# ZA       3
# AT       2
# MY       2
# UY       2
# SK       2
# HU       2
# CZ       2
# VN       2
# PR       2
# GT       2
# IS       2
# DO       1
# BO       1
# IL       1
# PY       1
# MU       1
# XC       1
# PT       1
# IR       1
# Name: Country, dtype: int64

# %%
top_10_rating = df.sort_values("Rating",ascending=False)[0:10]
top_10_rating
# Out:
#                                         Title       Date  Rating  \
# 4887                    Pretty Young Sister 4 2021-01-15   100.0
# 934                        Female Boss Hooker 2020-08-31   100.0
# 8232                              Housekeeper 2020-03-26   100.0
# 10046                                Simulant 2023-06-02   100.0
# 6433             Furin, hentai, monmon chômon 2019-10-25   100.0
# 443                              El asistente 2023-03-01   100.0
# 277                          Orgasm Lecture 2 2020-02-20   100.0
# 5404   The Chosen: Season 3  - Episodes 1 & 2 2022-11-18   100.0
# 7815                                  Rebound 2023-04-05    98.0
# 4755            Directing Annabelle: Creation 2017-08-07    93.0
#
#                            Genre  \
# 4887              Drama, Romance
# 934               Drama, Romance
# 8232                     Romance
# 10046  Science Fiction, Thriller
# 6433                       Drama
# 443                       Comedy
# 277                        Drama
# 5404              Drama, History
# 7815                       Drama
# 4755                 Documentary
#
#                                                 Overview  \
# 4887   Jeong-woo who is tired of instant food and liv...
# 934    Ji-cheol is a job seeker who only plays and ea...
# 8232   Min-woo, the consulate general of the overseas...
# 10046  Faye attempts to replace her newly deceased hu...
# 6433   Minoru is dead. However, he was conscious for ...
# 443    We don't have an overview translated in Englis...
# 277    Yuner, Liu Ren, and Zhou Xian are college girl...
# 5404   After Jesus completes a sermon that turns the ...
# 7815   Joong-Ang High School was once renowned for it...
# 4755   Director David F. Sandberg takes you through t...
#
#                                                    Actor  \
# 4887   Ha Yeon, , Shin Yeon-ho, , Kang Seo, , Yoon Da...
# 934    Ye Seul, , Lee Sul-ah-I, , Min Do-yoon, , Jo Y...
# 8232   Ahn So-hee, , Min Do-yoon, , Kang Min-woo, , H...
# 10046  Robbie Amell, Evan, Jordana Brewster, Faye, Si...
# 6433   Tomoka Takase, Maya Iizuka, Riona Suzushiro, S...
# 443    Rodrigo Noya, Miguel, Luis Cao, Jimmy, Florenc...
# 277    Min Do-yoon, , Park Soo-bin-III, , Hong Sae-he...
# 5404   Jonathan Roumie, Jesus, Noah James, Andrew, Pa...
# 7815   Ahn Jae-hong, Kang Yang-hyun, Lee Sin-young, C...
# 4755   David F. Sandberg, Himself, Talitha Bateman, H...
#
#                                 Orginal Title     Status     Orginal Language  \
# 4887                                 예쁜 여동생 4   Released               Korean
# 934                                   여사장 후리꾼   Released               Korean
# 8232                                     예쁜식모   Released               Korean
# 10046                          Hello Stranger   Released              English
# 6433                               不倫、変態、悶々弔問   Released             Japanese
# 443                              El asistente   Released   Spanish, Castilian
# 277                                 오르가즘 특강 2   Released               Korean
# 5404   The Chosen: Season 3  - Episodes 1 & 2   Released              English
# 7815                                     리바운드   Released               Korean
# 4755            Directing Annabelle: Creation   Released              English
#
#           Budget     Revenue Country
# 4887   201000000  1569323843      KR
# 934    201000000  1569323843      KR
# 8232   201000000  1569323843      KR
# 10046  201000000  1569323843      US
# 6433   201000000  1569323843      JP
# 443    201000000  1569323843      AR
# 277    201000000  1569323843      KR
# 5404   201000000  1569323843      US
# 7815    45000000    17492014      KR
# 4755   227800000  1644265184      US

# %% [markdown]
# ## **Exploratory Data Analysis: Univariate**

# %%
def generate_histogram(data, title, xlabel, ylabel, bins=10):
    """
    Generate a histogram plot.

    Parameters:
        data (list or array): Data to be plotted.
        title (str): Title of the plot.
        xlabel (str): Label for the x-axis.
        ylabel (str): Label for the y-axis.
        bins (int, optional): Number of bins for the histogram. Default is 10.

    Returns:
        None
    """
    plt.figure(figsize=(8, 6))
    plt.hist(data, bins=bins, color='skyblue', edgecolor='black')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.show()

# %%
def generate_bar_plot(categories, values, title, xlabel, ylabel):
    """
    Generate a bar plot.

    Parameters:
        categories (list or array): Categories or labels for the bars.
        values (list or array): Values corresponding to each category.
        title (str): Title of the plot.
        xlabel (str): Label for the x-axis.
        ylabel (str): Label for the y-axis.

    Returns:
        None
    """
    plt.figure(figsize=(10, 6))
    plt.bar(categories, values, color='skyblue')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
def generate_pie_chart(labels, sizes, title):
    """
    Generate a pie chart.

    Parameters:
        labels (list or array): Labels for each wedge of the pie.
        sizes (list or array): Sizes of each wedge.
        title (str): Title of the pie chart.

    Returns:
        None
    """
    plt.figure(figsize=(10, 10))
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title(title)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
def generate_scatter_plot(x_values, y_values, title, xlabel, ylabel):
    """
    Generate a scatter plot with two variables.

    Parameters:
        x_values (list or array): Values for the x-axis.
        y_values (list or array): Values for the y-axis.
        title (str): Title of the plot.
        xlabel (str): Label for the x-axis.
        ylabel (str): Label for the y-axis.

    Returns:
        None
    """
    plt.figure(figsize=(8, 6))
    plt.scatter(x_values, y_values, color='skyblue', alpha=0.7)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.show()

# %%
def generate_box_plot(data1, data2, labels, title, ylabel):
    """
    Generate a box plot based on two variables.

    Parameters:
        data1 (list or array): Values for the first variable.
        data2 (list or array): Values for the second variable.
        labels (list): Labels for the x-axis (usually representing the two variables).
        title (str): Title of the plot.
        ylabel (str): Label for the y-axis.

    Returns:
        None
    """
    plt.figure(figsize=(8, 6))
    plt.boxplot([data1, data2], labels=labels)
    plt.title(title)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.show()

# %% [markdown]
# **Let us explore the numerical variables first.**

# %% [markdown]
# ### **Visualization and Observations on Movie User Ratings** (oi)

# %%
generate_histogram(df['Rating'], "Visualiation of Movie Rating", "Rating", "Frequency")

# %% [markdown]
# **Observations:**
# * ...

# %% [markdown]
# **Now, let's explore the categorical variables.**

# %% [markdown]
# ### **Visualization and Observations on Budget** (oi)
#
# ---

# %%
generate_histogram(df['Budget'], "Visualiation of Budget", "Budget", "Frequency", 20)

# %% [markdown]
# **Observations:**
# * ...

# %% [markdown]
# **Now, let's explore the categorical variables.**

# %% [markdown]
# ### **Visualization and Observations on Revenue** (oi)
#
# ---

# %%
generate_histogram(df['Revenue'], "Visualiation of Revenue", "Budget", "Frequency", 20)

# %% [markdown]
# **Observations:**
# * ...

# %% [markdown]
# **Now, let's explore the categorical variables.**

# %% [markdown]
# ### **Visualization and Observations on Genre** (oi)

# %%
def extract_genres(genre_string):
    """
    Extract genres from a string containing one or more genres separated by commas.

    Parameters:
        genre_string (str): String containing one or more genres separated by commas.

    Returns:
        list: List of individual genres extracted from the input string.
    """
    if isinstance(genre_string, str):
        return [genre.strip() for genre in genre_string.split(',')]
    else:
        return []

class TallyAndUnique:
    def __init__(self):
        self.frequency_counter = Counter()
        self.unique_values = set()

    def update(self, lst):
        """
        Update the tally and unique values with a new list.

        Parameters:
            lst (list): Input list.
        """
        self.frequency_counter.update(lst)
        self.unique_values.update(lst)

    def get_results(self):
        """
        Compile the results into two lists: one for genre names and the other for their respective counts.

        Returns:
            tuple: A tuple containing two lists:
                - The first list contains genre names.
                - The second list contains counts corresponding to each genre.
        """
        genre_names = []
        counts = []
        for genre, count in self.frequency_counter.items():
            genre_names.append(genre)
            counts.append(count)
        return genre_names, counts

tally_unique_obj = TallyAndUnique()

extracted_genres = []

for genres in df['Genre']:
  genre_str = extract_genres(genres)
  tally_unique_obj.update(genre_str)

frequency_list, unique_list = tally_unique_obj.get_results()


generate_bar_plot(frequency_list, unique_list, "Visualization of Genre Count", "Genre", "Count")

# %% [markdown]
# **Observations:**
# * ...

# %% [markdown]
# ### **Visualization and Observations on Release Status** (oi)

# %%
tally_unique_status_obj = TallyAndUnique()

for status in df['Status']:
  release_status = tally_unique_status_obj.update([status])

status_frequency_list, status_unique_list = tally_unique_status_obj.get_results()

generate_pie_chart(status_frequency_list, status_unique_list, "Visualization of Movie Release Status")

# %% [markdown]
# **Observations:**
# * ...

# %% [markdown]
# [Rinse and Repeat for different plots...]

# %% [markdown]
# ### **Observations on [...]**

# %% [markdown]
# **Observations:**
# * ...

# %% [markdown]
# [Rinse and Repeat for different plots...]

# %% [markdown]
# ## **Exploratory Data Analysis: Multivariate**

# %% [markdown]
# **Now, let's explore the categorical variables.**

# %% [markdown]
# ### **Visualization and Observations on Budget vs Revenue** (oi)

# %% [markdown]
# **Observations:**
# * ...

# %% [markdown]
# ### **Visualization and Observations on Orginal Languiage vs Revenue** (JOB)

# %%
# Adjusting the approach to focus on the top 10 revenues vs. original language, based on a simulated dataset.
# Since the actual data is not available, I'll simulate a dataset with 'Original Language' and 'Revenue'.

# Creating a mock dataset with 'Original Language' and 'Revenue'
data_lang = {
    'Original Language': ['English', 'French', 'Spanish', 'German', 'Japanese', 'Mandarin', 'Hindi', 'Korean', 'Italian', 'Russian'],
    'Revenue': [300000, 150000, 200000, 180000, 210000, 250000, 220000, 190000, 160000, 230000]
}

df_lang = pd.DataFrame(data_lang)

# Sorting languages by total revenue and selecting the top 10
top_languages_10 = df_lang.sort_values(by='Revenue', ascending=False).head(10)

# Plotting for the top 10 original languages
plt.figure(figsize=(12, 7))
plt.scatter(top_languages_10['Original Language'], top_languages_10['Revenue'], color='purple', alpha=0.5, s=100)
plt.title('Top 10 Original Languages by Total Revenue')
plt.xlabel('Original Language')
plt.xticks(rotation=45)  # Rotate language names for better visibility
plt.ylabel('Total Revenue')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Visualization and Observations on Country vs Revenue** (JOB)

# %%
# Aggregating total revenue by country
country_revenue = df_movies.groupby('country')['revenue'].sum().reset_index()

# Sorting by revenue for better visualization
country_revenue_sorted = country_revenue.sort_values(by='revenue', ascending=False)

# Creating the scatter plot for country vs total revenue
plt.figure(figsize=(10, 6))
sns.scatterplot(data=country_revenue_sorted, x='country', y='revenue')
plt.title('Total Revenue by Country')
plt.xlabel('Country')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()

# This plot will show each country's total revenue from movies, helping to visualize which countries have the highest revenue generation from the dataset.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-8bd35660221f> in <cell line: 2>()
#       1 # Aggregating total revenue by country
# ----> 2 country_revenue = df_movies.groupby('country')['revenue'].sum().reset_index()
#       3
#       4 # Sorting by revenue for better visualization
#       5 country_revenue_sorted = country_revenue.sort_values(by='revenue', ascending=False)
#
# NameError: name 'df_movies' is not defined

# %% [markdown]
# ### **Visualization and Observations on Genre vs Revenue** (JOB)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Since there could be many countries, let's first check the distribution of movies across countries
country_counts = df_movies['country'].value_counts()

# Plotting the distribution of movies by country to decide on how to visualize country vs revenue
plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values)
plt.title('Distribution of Movies by Country')
plt.xlabel('Country')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.show()

# For the "country vs revenue" scatter plot, considering the visualization above, we might aggregate or select top countries.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-5e0617b52d78> in <cell line: 5>()
#       3
#       4 # Since there could be many countries, let's first check the distribution of movies across countries
# ----> 5 country_counts = df_movies['country'].value_counts()
#       6
#       7 # Plotting the distribution of movies by country to decide on how to visualize country vs revenue
#
# NameError: name 'df_movies' is not defined

# %% [markdown]
# **Now, let's explore the categorical variables.**

# %% [markdown]
# [Rinse and Repeat (same idea as the univariate) for different plots...]

# %% [markdown]
# ### **Visualization and Observations on User Score by Original Language** (oi)

# %%
# if df['score'].dtype == 'object':
#     df['score'] = df['score'].astype(float)
# elif df['orig_lang'].dtype == 'object':
#     df['orig_lang'] = df['orig_lang'].astype('category')


#generate_box_plot(df[['score']], df[['orig_lang']], ["User Score", "Released Language"], "Analysis Comparing User Score by Original Language", df['orig_lang'])

# %% [markdown]
# **Observations:**
# * ...

# %% [markdown]
# **Now, let's explore the categorical variables.**

# %% [markdown]
# [Rinse and Repeat (same idea as the univariate) for different plots...]

# %% [markdown]
# ## **Conclusion and Recommendations**

# %% [markdown]
# -----------------------------------------------------------------
# ### **Conclusion**
# -----------------------------------------------------------------
#
# We analyzed a dataset of nearly ...
# The data spanned ...
# The main feature of interest here is the ...
# From a business perspective, ...
# Thus, we determined the factors that affect ...
#
# We have been able to conclude that:
#
# 1. ...
#
# --------------------------------------------------
# ### **Recommendation to business**
# --------------------------------------------------
#
# 1. ...
#
# ---------------------------------
# ###  **Further Analysis**
# ---------------------------------
# 1. Dig deeper to explore the variation of ...
